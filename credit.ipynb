# %% [markdown]
# # Credit Risk Prediction System ⭐

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cs-training.csv")
df.sample(20)
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 35092        35093                 0                              0.000000
# 95868        95869                 0                              0.038286
# 44094        44095                 0                              0.227530
# 60627        60628                 0                              0.394264
# 10376        10377                 0                              0.128120
# 97041        97042                 0                              0.077424
# 55193        55194                 0                              0.115427
# 76309        76310                 0                              0.340355
# 116789      116790                 0                              0.175909
# 58400        58401                 0                              0.054134
# 85718        85719                 0                              0.075550
# 137989      137990                 0                              0.053770
# 73463        73464                 0                              0.168189
# 92508        92509                 1                              0.302621
# 24531        24532                 0                              0.054882
# 132380      132381                 0                              0.122781
# 45771        45772                 0                              0.056472
# 145955      145956                 0                              0.285903
# 95041        95042                 0                              0.040095
# 54359        54360                 0                              0.266582
#
#         age  NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 35092    53                                     0     0.302340         5000.0
# 95868    66                                     0     0.344990        11266.0
# 44094    50                                     0     0.420833         6700.0
# 60627    35                                     1     0.166825         8409.0
# 10376    46                                     0     0.540608         2400.0
# 97041    49                                     0     0.528893         6800.0
# 55193    89                                     0     0.159194         6400.0
# 76309    67                                     0     0.292683         2500.0
# 116789   73                                     0     0.021541         6916.0
# 58400    59                                     0     0.412240         6437.0
# 85718    72                                     0     0.013998         9000.0
# 137989   66                                     0     0.759371        10750.0
# 73463    39                                     0     0.241152         5000.0
# 92508    54                                     1     0.085497         8666.0
# 24531    86                                     0     0.408255         3100.0
# 132380   63                                     0     0.391753         3200.0
# 45771    48                                     0  1190.000000            NaN
# 145955   40                                     0     0.417930         6000.0
# 95041    59                                     0   113.000000            NaN
# 54359    29                                     0   327.000000            0.0
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 35092                                 9                        0
# 95868                                12                        0
# 44094                                 9                        0
# 60627                                12                        0
# 10376                                10                        0
# 97041                                 6                        0
# 55193                                 8                        0
# 76309                                 4                        0
# 116789                                3                        0
# 58400                                 6                        0
# 85718                                 3                        0
# 137989                               11                        0
# 73463                                11                        0
# 92508                                 8                        0
# 24531                                 5                        0
# 132380                                7                        0
# 45771                                11                        0
# 145955                               17                        0
# 95041                                 5                        0
# 54359                                 1                        0
#
#         NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 35092                              1                                     0
# 95868                              2                                     0
# 44094                              1                                     0
# 60627                              0                                     0
# 10376                              2                                     0
# 97041                              2                                     0
# 55193                              1                                     0
# 76309                              0                                     0
# 116789                             0                                     0
# 58400                              1                                     0
# 85718                              0                                     0
# 137989                             6                                     0
# 73463                              1                                     0
# 92508                              0                                     0
# 24531                              2                                     0
# 132380                             1                                     0
# 45771                              0                                     0
# 145955                             1                                     0
# 95041                              0                                     0
# 54359                              0                                     1
#
#         NumberOfDependents
# 35092                  2.0
# 95868                  0.0
# 44094                  0.0
# 60627                  3.0
# 10376                  0.0
# 97041                  5.0
# 55193                  0.0
# 76309                  0.0
# 116789                 0.0
# 58400                  1.0
# 85718                  0.0
# 137989                 1.0
# 73463                  3.0
# 92508                  0.0
# 24531                  0.0
# 132380                 0.0
# 45771                  0.0
# 145955                 0.0
# 95041                  0.0
# 54359                  0.0

# %%
df.rename(columns={'SeriousDlqin2yrs': 'Default_Status'}, inplace=True)

# %%
df.rename(columns={'RevolvingUtilizationOfUnsecuredLines': 'Credit_Utilization'}, inplace=True)

# %%
df.rename(columns={'NumberOfTime30-59DaysPastDueNotWorse': 'Late_30_59_Days'}, inplace=True)

# %%
df.rename(columns={'NumberOfTime60-89DaysPastDueNotWorse': 'Late_60_89_Days'}, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Default_Status  Credit_Utilization  age  Late_30_59_Days  \
# 0           1               1            0.766127   45                2
# 1           2               0            0.957151   40                0
# 2           3               0            0.658180   38                1
# 3           4               0            0.233810   30                0
# 4           5               0            0.907239   49                1
#
#    DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 0   0.802982         9120.0                               13
# 1   0.121876         2600.0                                4
# 2   0.085113         3042.0                                2
# 3   0.036050         3300.0                                5
# 4   0.024926        63588.0                                7
#
#    NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  Late_60_89_Days  \
# 0                        0                             6                0
# 1                        0                             0                0
# 2                        1                             0                0
# 3                        0                             0                0
# 4                        0                             1                0
#
#    NumberOfDependents
# 0                 2.0
# 1                 1.0
# 2                 0.0
# 3                 0.0
# 4                 0.0

# %% [markdown]
# # Data Preprocess

# %% [markdown]
# df.info()

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df['Default_Status'].value_counts(normalize=True)
# Out:
# Default_Status
# 0    0.93316
# 1    0.06684
# Name: proportion, dtype: float64

# %%
df.isnull().sum()
# Out:
# Default_Status                         0
# Credit_Utilization                     0
# age                                    0
# Late_30_59_Days                        0
# DebtRatio                              0
# MonthlyIncome                      29731
# NumberOfOpenCreditLinesAndLoans        0
# NumberOfTimes90DaysLate                0
# NumberRealEstateLoansOrLines           0
# Late_60_89_Days                        0
# NumberOfDependents                  3924
# dtype: int64

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].fillna(df['MonthlyIncome'].median())

# %%
df['NumberOfDependents'] = df['NumberOfDependents'].fillna(df['NumberOfDependents'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Default_Status                     0
# Credit_Utilization                 0
# age                                0
# Late_30_59_Days                    0
# DebtRatio                          0
# MonthlyIncome                      0
# NumberOfOpenCreditLinesAndLoans    0
# NumberOfTimes90DaysLate            0
# NumberRealEstateLoansOrLines       0
# Late_60_89_Days                    0
# NumberOfDependents                 0
# dtype: int64

# %%
df['NumberOfDependents'] = df['NumberOfDependents'].astype(int)
df['MonthlyIncome'] = df['MonthlyIncome'].astype(int)

# %%
df = df[(df['age'] >= 18) & (df['age'] <= 100)].copy()
df['age'] = df['age'].astype(int)
print(df['age'].dtype)
# Out:
# int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 149986 entries, 0 to 149999
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Default_Status                   149986 non-null  int64
#  1   Credit_Utilization               149986 non-null  float64
#  2   age                              149986 non-null  int64
#  3   Late_30_59_Days                  149986 non-null  int64
#  4   DebtRatio                        149986 non-null  float64
#  5   MonthlyIncome                    149986 non-null  int64
#  6   NumberOfOpenCreditLinesAndLoans  149986 non-null  int64
#  7   NumberOfTimes90DaysLate          149986 non-null  int64
#  8   NumberRealEstateLoansOrLines     149986 non-null  int64
#  9   Late_60_89_Days                  149986 non-null  int64
#  10  NumberOfDependents               149986 non-null  int64
# dtypes: float64(2), int64(9)
# memory usage: 13.7 MB

# %%
df[['Late_30_59_Days','Late_60_89_Days','NumberOfTimes90DaysLate']].describe()
# Out:
#        Late_30_59_Days  Late_60_89_Days  NumberOfTimes90DaysLate
# count    149986.000000    149986.000000            149986.000000
# mean          0.421053         0.240409                 0.265998
# std           4.192973         4.155373                 4.169498
# min           0.000000         0.000000                 0.000000
# 25%           0.000000         0.000000                 0.000000
# 50%           0.000000         0.000000                 0.000000
# 75%           0.000000         0.000000                 0.000000
# max          98.000000        98.000000                98.000000

# %%
df[['Credit_Utilization','DebtRatio','MonthlyIncome']].describe()
# Out:
#        Credit_Utilization      DebtRatio  MonthlyIncome
# count       149986.000000  149986.000000   1.499860e+05
# mean             6.048985     353.002995   6.418676e+03
# std            249.767020    2037.902441   1.289096e+04
# min              0.000000       0.000000   0.000000e+00
# 25%              0.029878       0.175075   3.903250e+03
# 50%              0.154234       0.366503   5.400000e+03
# 75%              0.559053       0.868100   7.400000e+03
# max          50708.000000  329664.000000   3.008750e+06

# %%
late_cols = ['Late_30_59_Days','Late_60_89_Days','NumberOfTimes90DaysLate']

for col in late_cols:
    df[col] = df[col].replace([96,97,98], df[col].median())

# %%
for col in ['Credit_Utilization','DebtRatio','MonthlyIncome']:
    lower = df[col].quantile(0.01)
    upper = df[col].quantile(0.99)
    df[col] = df[col].clip(lower, upper)

# %%
df[['Late_30_59_Days',
    'Late_60_89_Days',
    'NumberOfTimes90DaysLate',
    'Credit_Utilization',
    'DebtRatio',
    'MonthlyIncome']].describe()
# Out:
#        Late_30_59_Days  Late_60_89_Days  NumberOfTimes90DaysLate  \
# count    149986.000000    149986.000000            149986.000000
# mean          0.245356         0.064713                 0.090302
# std           0.697243         0.329803                 0.485129
# min           0.000000         0.000000                 0.000000
# 25%           0.000000         0.000000                 0.000000
# 50%           0.000000         0.000000                 0.000000
# 75%           0.000000         0.000000                 0.000000
# max          13.000000        11.000000                17.000000
#
#        Credit_Utilization      DebtRatio  MonthlyIncome
# count       149986.000000  149986.000000  149986.000000
# mean             0.320508     316.548985    6142.640846
# std              0.352152     907.008053    3835.763455
# min              0.000000       0.000000       0.000000
# 25%              0.029878       0.175075    3903.250000
# 50%              0.154234       0.366503    5400.000000
# 75%              0.559053       0.868100    7400.000000
# max              1.092987    4979.600000   23000.000000

# %%
import numpy as np
df['DebtRatio'] = np.log1p(df['DebtRatio'])

# %%
df['DebtRatio'].describe()
# Out:
# count    149986.000000
# mean          1.521618
# std           2.617369
# min           0.000000
# 25%           0.161332
# 50%           0.312255
# 75%           0.624922
# max           8.513306
# Name: DebtRatio, dtype: float64

# %%
df.sample(2)
# Out:
#         Default_Status  Credit_Utilization  age  Late_30_59_Days  DebtRatio  \
# 455                  0            0.067901   69                0   0.063438
# 123471               0            0.038168   84                0   0.091850
#
#         MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 455             10000                                5
# 123471           4500                                5
#
#         NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  \
# 455                           0                             1
# 123471                        0                             0
#
#         Late_60_89_Days  NumberOfDependents
# 455                   0                   0
# 123471                0                   1

# %%
df['DebtRatio'].describe()
# Out:
# count    149986.000000
# mean          1.521618
# std           2.617369
# min           0.000000
# 25%           0.161332
# 50%           0.312255
# 75%           0.624922
# max           8.513306
# Name: DebtRatio, dtype: float64

# %%
sns.histplot(df['DebtRatio'], kde=True)
# Out:
# <Axes: xlabel='DebtRatio', ylabel='Count'>

# %% [markdown]
# # Feature Engineering

# %%
df['TotalLatePayments'] = (df['Late_30_59_Days'] +df['Late_60_89_Days'] +df['NumberOfTimes90DaysLate'])

# %%
df['TotalLatePayments']
# Out:
# 0         2
# 1         0
# 2         2
# 3         0
# 4         1
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: TotalLatePayments, Length: 149986, dtype: int64

# %%
df['Any90DayLate'] = (
    df['NumberOfTimes90DaysLate'] > 0
).astype(int)

# %%
df['Any90DayLate']
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: Any90DayLate, Length: 149986, dtype: int64

# %%
df['IncomePerDependent'] = (df['MonthlyIncome'] /(df['NumberOfDependents'] + 1))

# %%
df['IncomePerDependent']
# Out:
# 0          3040.000000
# 1          1300.000000
# 2          3042.000000
# 3          3300.000000
# 4         23000.000000
#               ...
# 149995     2100.000000
# 149996     1861.333333
# 149997     5400.000000
# 149998     5716.000000
# 149999     8158.000000
# Name: IncomePerDependent, Length: 149986, dtype: float64

# %%
df['TotalCreditLines'] = (df['NumberOfOpenCreditLinesAndLoans'] +df['NumberRealEstateLoansOrLines'])
df['TotalCreditLines']
# Out:
# 0         19
# 1          4
# 2          2
# 3          5
# 4          8
#           ..
# 149995     5
# 149996     5
# 149997    19
# 149998     4
# 149999    10
# Name: TotalCreditLines, Length: 149986, dtype: int64

# %%
df['HighUtilizationFlag'] = (df['Credit_Utilization'] > 0.75).astype(int)
df['HighUtilizationFlag']
# Out:
# 0         1
# 1         1
# 2         0
# 3         0
# 4         1
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    1
# Name: HighUtilizationFlag, Length: 149986, dtype: int64

# %%
df['DebtLoad'] = (df['DebtRatio'] * df['MonthlyIncome'])
df['DebtLoad']
# Out:
# 0          5375.711335
# 1           299.006404
# 2           248.484172
# 3           116.869824
# 4           566.262697
#               ...
# 149995      426.400143
# 149996     3017.166879
# 149997    44610.848013
# 149998        0.000000
# 149999     1819.805143
# Name: DebtLoad, Length: 149986, dtype: float64

# %%
df['LatePerCreditLine'] = ( df['TotalLatePayments'] /(df['TotalCreditLines'] + 1))
df['LatePerCreditLine']
# Out:
# 0         0.100000
# 1         0.000000
# 2         0.666667
# 3         0.000000
# 4         0.111111
#             ...
# 149995    0.000000
# 149996    0.000000
# 149997    0.000000
# 149998    0.000000
# 149999    0.000000
# Name: LatePerCreditLine, Length: 149986, dtype: float64

# %%
df['UtilizationPerLine'] = (df['Credit_Utilization'] /(df['TotalCreditLines'] + 1))
df['UtilizationPerLine']
# Out:
# 0         0.038306
# 1         0.191430
# 2         0.219393
# 3         0.038968
# 4         0.100804
#             ...
# 149995    0.006779
# 149996    0.049958
# 149997    0.012302
# 149998    0.000000
# 149999    0.077298
# Name: UtilizationPerLine, Length: 149986, dtype: float64

# %%
df['HasDependents'] = (df['NumberOfDependents'] > 0).astype(int)
df['HasDependents']
# Out:
# 0         1
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    1
# 149997    0
# 149998    0
# 149999    0
# Name: HasDependents, Length: 149986, dtype: int64

# %%
df['SeniorFlag'] = (df['age'] >= 60).astype(int)
df['SeniorFlag']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    1
# 149996    0
# 149997    0
# 149998    0
# 149999    1
# Name: SeniorFlag, Length: 149986, dtype: int64

# %%
df['ZeroIncomeFlag'] = (df['MonthlyIncome'] == 0).astype(int)
df['ZeroIncomeFlag']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: ZeroIncomeFlag, Length: 149986, dtype: int64

# %%
df.sample(2)
# Out:
#         Default_Status  Credit_Utilization  age  Late_30_59_Days  DebtRatio  \
# 140283               0            0.061403   63                0   6.694562
# 4715                 0            0.000000   32                0   0.376008
#
#         MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 140283           5400                                4
# 4715             2755                                3
#
#         NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  \
# 140283                        0                             2
# 4715                          0                             1
#
#         Late_60_89_Days  ...  Any90DayLate  IncomePerDependent  \
# 140283                0  ...             0              5400.0
# 4715                  0  ...             0              2755.0
#
#         TotalCreditLines  HighUtilizationFlag      DebtLoad  \
# 140283                 6                    0  36150.635116
# 4715                   4                    0   1035.901757
#
#         LatePerCreditLine  UtilizationPerLine  HasDependents  SeniorFlag  \
# 140283                0.0            0.008772              0           1
# 4715                  0.0            0.000000              0           0
#
#         ZeroIncomeFlag
# 140283               0
# 4715                 0
#
# [2 rows x 22 columns]

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)

# %%
sns.countplot(x='Default_Status', data=df)
plt.title("Default Status Distribution")
plt.show()

# %%
sns.boxplot(x='Default_Status', y='age', data=df)
plt.title("Default vs Age")
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
df.corr()['Default_Status'].sort_values(ascending=False)
# Out:
# Default_Status                     1.000000
# TotalLatePayments                  0.388653
# Any90DayLate                       0.329616
# LatePerCreditLine                  0.313697
# NumberOfTimes90DaysLate            0.311729
# Credit_Utilization                 0.280856
# Late_30_59_Days                    0.271364
# Late_60_89_Days                    0.265608
# HighUtilizationFlag                0.262462
# UtilizationPerLine                 0.189373
# NumberOfDependents                 0.046878
# HasDependents                      0.043532
# NumberRealEstateLoansOrLines      -0.007028
# ZeroIncomeFlag                    -0.011114
# DebtLoad                          -0.017066
# DebtRatio                         -0.017337
# TotalCreditLines                  -0.028041
# NumberOfOpenCreditLinesAndLoans   -0.029667
# MonthlyIncome                     -0.049784
# IncomePerDependent                -0.062114
# SeniorFlag                        -0.098823
# age                               -0.115470
# Name: Default_Status, dtype: float64

# %%
sns.histplot(df['Credit_Utilization'], kde=True)
plt.title("Credit Utilization Distribution")
# Out:
# Text(0.5, 1.0, 'Credit Utilization Distribution')

# %%
sns.boxplot(x='Default_Status', y='TotalCreditLines', data=df)
# Out:
# <Axes: xlabel='Default_Status', ylabel='TotalCreditLines'>

# %%
df['AgeGroup'] = pd.cut(df['age'],
                        bins=[18,30,45,60,100],
                        labels=['18-30','31-45','46-60','60+'])

sns.barplot(x='AgeGroup', y='Default_Status', data=df)
# Out:
# <Axes: xlabel='AgeGroup', ylabel='Default_Status'>

# %%
sns.boxplot(x='AgeGroup', y='MonthlyIncome', data=df)
# Out:
# <Axes: xlabel='AgeGroup', ylabel='MonthlyIncome'>

# %%
sample = df.sample(1000, random_state=42)

sns.pairplot(sample[
['age','MonthlyIncome','DebtRatio','Credit_Utilization','Default_Status']],
hue='Default_Status')

# %%
sns.scatterplot(x='Credit_Utilization',
                y='TotalLatePayments',
                hue='Default_Status',
                data=df.sample(3000))
# Out:
# <Axes: xlabel='Credit_Utilization', ylabel='TotalLatePayments'>

# %%
(df['Default_Status'].value_counts(normalize=True)*100).plot(kind='bar')
plt.title("Default Percentage")
# Out:
# Text(0.5, 1.0, 'Default Percentage')

# %%
import sweetviz as sv

report = sv.analyze(df)
report.show_html("sweetviz_report.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.sample(5)
# Out:
#         Default_Status  Credit_Utilization  age  Late_30_59_Days  DebtRatio  \
# 101516               0            1.000000   57                0   8.043984
# 140447               1            0.822899   49                1   0.356897
# 76736                0            0.217223   41                0   0.333172
# 148623               0            0.729985   40                0   0.409482
# 46563                0            1.092987   58                1   0.037925
#
#         MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# 101516           5400                                4
# 140447           7649                               18
# 76736            6633                                7
# 148623           7536                                9
# 46563            3000                                4
#
#         NumberOfTimes90DaysLate  NumberRealEstateLoansOrLines  \
# 101516                        0                             1
# 140447                        0                             1
# 76736                         0                             0
# 148623                        0                             1
# 46563                         3                             0
#
#         Late_60_89_Days  ...  IncomePerDependent  TotalCreditLines  \
# 101516                0  ...         5400.000000                 5
# 140447                0  ...         2549.666667                19
# 76736                 0  ...         2211.000000                 7
# 148623                0  ...         1884.000000                10
# 46563                 1  ...         3000.000000                 4
#
#         HighUtilizationFlag      DebtLoad  LatePerCreditLine  \
# 101516                    1  43437.515929               0.00
# 140447                    1   2729.906236               0.05
# 76736                     0   2209.930416               0.00
# 148623                    0   3085.853497               0.00
# 46563                     1    113.776303               1.00
#
#         UtilizationPerLine  HasDependents  SeniorFlag  ZeroIncomeFlag  \
# 101516            0.166667              0           0               0
# 140447            0.041145              1           0               0
# 76736             0.027153              1           0               0
# 148623            0.066362              1           0               0
# 46563             0.218597              0           0               0
#
#         AgeGroup
# 101516     46-60
# 140447     46-60
# 76736      31-45
# 148623     31-45
# 46563      46-60
#
# [5 rows x 23 columns]

# %% [markdown]
# # . Model Algorithms

# %%
X = df.drop(['Default_Status', 'AgeGroup'], axis=1)
y = df['Default_Status']

# %%
X
# Out:
#         Credit_Utilization  age  Late_30_59_Days  DebtRatio  MonthlyIncome  \
# 0                 0.766127   45                2   0.589442           9120
# 1                 0.957151   40                0   0.115002           2600
# 2                 0.658180   38                1   0.081684           3042
# 3                 0.233810   30                0   0.035415           3300
# 4                 0.907239   49                1   0.024620          23000
# ...                    ...  ...              ...        ...            ...
# 149995            0.040674   74                0   0.203048           2100
# 149996            0.299745   44                0   0.540324           5584
# 149997            0.246044   58                0   8.261268           5400
# 149998            0.000000   30                0   0.000000           5716
# 149999            0.850283   64                0   0.223070           8158
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                                    13                        0
# 1                                     4                        0
# 2                                     2                        1
# 3                                     5                        0
# 4                                     7                        0
# ...                                 ...                      ...
# 149995                                4                        0
# 149996                                4                        0
# 149997                               18                        0
# 149998                                4                        0
# 149999                                8                        0
#
#         NumberRealEstateLoansOrLines  Late_60_89_Days  NumberOfDependents  \
# 0                                  6                0                   2
# 1                                  0                0                   1
# 2                                  0                0                   0
# 3                                  0                0                   0
# 4                                  1                0                   0
# ...                              ...              ...                 ...
# 149995                             1                0                   0
# 149996                             1                0                   2
# 149997                             1                0                   0
# 149998                             0                0                   0
# 149999                             2                0                   0
#
#         ...  Any90DayLate  IncomePerDependent  TotalCreditLines  \
# 0       ...             0         3040.000000                19
# 1       ...             0         1300.000000                 4
# 2       ...             1         3042.000000                 2
# 3       ...             0         3300.000000                 5
# 4       ...             0        23000.000000                 8
# ...     ...           ...                 ...               ...
# 149995  ...             0         2100.000000                 5
# 149996  ...             0         1861.333333                 5
# 149997  ...             0         5400.000000                19
# 149998  ...             0         5716.000000                 4
# 149999  ...             0         8158.000000                10
#
#         HighUtilizationFlag      DebtLoad  LatePerCreditLine  \
# 0                         1   5375.711335           0.100000
# 1                         1    299.006404           0.000000
# 2                         0    248.484172           0.666667
# 3                         0    116.869824           0.000000
# 4                         1    566.262697           0.111111
# ...                     ...           ...                ...
# 149995                    0    426.400143           0.000000
# 149996                    0   3017.166879           0.000000
# 149997                    0  44610.848013           0.000000
# 149998                    0      0.000000           0.000000
# 149999                    1   1819.805143           0.000000
#
#         UtilizationPerLine  HasDependents  SeniorFlag  ZeroIncomeFlag
# 0                 0.038306              1           0               0
# 1                 0.191430              1           0               0
# 2                 0.219393              0           0               0
# 3                 0.038968              0           0               0
# 4                 0.100804              0           0               0
# ...                    ...            ...         ...             ...
# 149995            0.006779              0           1               0
# 149996            0.049958              1           0               0
# 149997            0.012302              0           0               0
# 149998            0.000000              0           0               0
# 149999            0.077298              0           1               0
#
# [149986 rows x 21 columns]

# %%
y
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: Default_Status, Length: 149986, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,stratify=y,random_state=42)

# %%
X_train
# Out:
#        Credit_Utilization  age  Late_30_59_Days  DebtRatio  MonthlyIncome  \
# 89038            1.000000   26                0   0.000000           1600
# 76578            0.092256   48                0   0.374491          13300
# 14675            1.092987   35                2   0.584035           2877
# 47863            0.319296   58                0   0.479235           3800
# 86609            0.031614   46                0   0.262339           9200
# ...                   ...  ...              ...        ...            ...
# 68160            0.037411   34                0   0.076007           6951
# 34886            0.000000   56                0   0.174774           3900
# 3736             0.485378   63                0   7.238497           5400
# 30299            0.276532   34                0   0.066656           2770
# 74899            0.000462   70                0   0.108786           1835
#
#        NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 89038                                0                        0
# 76578                               17                        0
# 14675                                5                        1
# 47863                                6                        0
# 86609                                8                        0
# ...                                ...                      ...
# 68160                                8                        0
# 34886                                9                        0
# 3736                                 5                        0
# 30299                                6                        0
# 74899                                6                        0
#
#        NumberRealEstateLoansOrLines  Late_60_89_Days  NumberOfDependents  ...  \
# 89038                             0                0                   1  ...
# 76578                             2                0                   0  ...
# 14675                             2                2                   0  ...
# 47863                             1                0                   0  ...
# 86609                             2                0                   3  ...
# ...                             ...              ...                 ...  ...
# 68160                             0                0                   0  ...
# 34886                             0                0                   1  ...
# 3736                              1                0                   0  ...
# 30299                             0                0                   0  ...
# 74899                             1                0                   0  ...
#
#        Any90DayLate  IncomePerDependent  TotalCreditLines  \
# 89038             0               800.0                 0
# 76578             0             13300.0                19
# 14675             1              2877.0                 7
# 47863             0              3800.0                 7
# 86609             0              2300.0                10
# ...             ...                 ...               ...
# 68160             0              6951.0                 8
# 34886             0              1950.0                 9
# 3736              0              5400.0                 6
# 30299             0              2770.0                 6
# 74899             0              1835.0                 7
#
#        HighUtilizationFlag      DebtLoad  LatePerCreditLine  \
# 89038                    1      0.000000              0.000
# 76578                    0   4980.735308              0.000
# 14675                    1   1680.267978              0.625
# 47863                    0   1821.092110              0.000
# 86609                    0   2413.520487              0.000
# ...                    ...           ...                ...
# 68160                    0    528.324361              0.000
# 34886                    0    681.617446              0.000
# 3736                     0  39087.882941              0.000
# 30299                    0    184.638367              0.000
# 74899                    0    199.622336              0.000
#
#        UtilizationPerLine  HasDependents  SeniorFlag  ZeroIncomeFlag
# 89038            1.000000              1           0               0
# 76578            0.004613              0           0               0
# 14675            0.136623              0           0               0
# 47863            0.039912              0           0               0
# 86609            0.002874              1           0               0
# ...                   ...            ...         ...             ...
# 68160            0.004157              0           0               0
# 34886            0.000000              1           0               0
# 3736             0.069340              0           1               0
# 30299            0.039505              0           0               0
# 74899            0.000058              0           1               0
#
# [119988 rows x 21 columns]

# %%
X_test
# Out:
#         Credit_Utilization  age  Late_30_59_Days  DebtRatio  MonthlyIncome  \
# 92230             0.117364   63                0   0.358549           5970
# 146800            0.737316   50                1   0.195833           7816
# 76051             0.451655   56                0   0.297471           5336
# 117643            0.158179   52                0   0.252203           6626
# 21984             0.892104   34                0   0.422400           4000
# ...                    ...  ...              ...        ...            ...
# 64339             0.000000   50                0   0.163137           7200
# 10479             0.986716   36                0   0.452893           1900
# 86558             0.054085   65                0   0.488637           4000
# 53577             0.400875   59                0   0.416621           7338
# 73688             0.006555   39                0   0.004604           5200
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 92230                                 7                        0
# 146800                                5                        0
# 76051                                11                        0
# 117643                                6                        0
# 21984                                 6                        1
# ...                                 ...                      ...
# 64339                                 9                        0
# 10479                                 5                        0
# 86558                                20                        0
# 53577                                15                        0
# 73688                                 9                        0
#
#         NumberRealEstateLoansOrLines  Late_60_89_Days  NumberOfDependents  \
# 92230                              2                0                   0
# 146800                             1                0                   2
# 76051                              1                0                   3
# 117643                             1                0                   0
# 21984                              0                0                   0
# ...                              ...              ...                 ...
# 64339                              2                0                   1
# 10479                              0                0                   0
# 86558                              2                0                   0
# 53577                              2                0                   0
# 73688                              0                0                   1
#
#         ...  Any90DayLate  IncomePerDependent  TotalCreditLines  \
# 92230   ...             0         5970.000000                 9
# 146800  ...             0         2605.333333                 6
# 76051   ...             0         1334.000000                12
# 117643  ...             0         6626.000000                 7
# 21984   ...             1         4000.000000                 6
# ...     ...           ...                 ...               ...
# 64339   ...             0         3600.000000                11
# 10479   ...             0         1900.000000                 5
# 86558   ...             0         4000.000000                22
# 53577   ...             0         7338.000000                17
# 73688   ...             0         2600.000000                 9
#
#         HighUtilizationFlag     DebtLoad  LatePerCreditLine  \
# 92230                     0  2140.537051           0.000000
# 146800                    0  1530.628387           0.142857
# 76051                     0  1587.305209           0.000000
# 117643                    0  1671.094788           0.000000
# 21984                     1  1689.599856           0.142857
# ...                     ...          ...                ...
# 64339                     0  1174.584297           0.000000
# 10479                     1   860.497315           0.000000
# 86558                     0  1954.546990           0.000000
# 53577                     0  3057.166735           0.000000
# 73688                     0    23.940191           0.000000
#
#         UtilizationPerLine  HasDependents  SeniorFlag  ZeroIncomeFlag
# 92230             0.011736              0           1               0
# 146800            0.105331              1           0               0
# 76051             0.034743              1           0               0
# 117643            0.019772              0           0               0
# 21984             0.127443              0           0               0
# ...                    ...            ...         ...             ...
# 64339             0.000000              1           0               0
# 10479             0.164453              0           0               0
# 86558             0.002352              0           1               0
# 53577             0.022271              0           0               0
# 73688             0.000656              1           0               0
#
# [29998 rows x 21 columns]

# %%
y_train
# Out:
# 89038    0
# 76578    0
# 14675    1
# 47863    0
# 86609    0
#         ..
# 68160    0
# 34886    0
# 3736     0
# 30299    0
# 74899    0
# Name: Default_Status, Length: 119988, dtype: int64

# %%
y_test
# Out:
# 92230     0
# 146800    1
# 76051     0
# 117643    0
# 21984     0
#          ..
# 64339     0
# 10479     0
# 86558     0
# 53577     0
# 73688     0
# Name: Default_Status, Length: 29998, dtype: int64

# %%
y_train.value_counts(normalize=True)
y_test.value_counts(normalize=True)
# Out:
# Default_Status
# 0    0.933162
# 1    0.066838
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
X_train_res
# Out:
#         Credit_Utilization  age  Late_30_59_Days  DebtRatio  MonthlyIncome  \
# 0                 1.000000   26                0   0.000000           1600
# 1                 0.092256   48                0   0.374491          13300
# 2                 1.092987   35                2   0.584035           2877
# 3                 0.319296   58                0   0.479235           3800
# 4                 0.031614   46                0   0.262339           9200
# ...                    ...  ...              ...        ...            ...
# 223931            0.684280   58                0   1.185510           1861
# 223932            0.773194   37                2   0.599177           6508
# 223933            0.770470   57                3   0.545644           7627
# 223934            0.684690   39                2   0.347891           5893
# 223935            0.791136   46                1   0.114010          10308
#
#         NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                                     0                        0
# 1                                    17                        0
# 2                                     5                        1
# 3                                     6                        0
# 4                                     8                        0
# ...                                 ...                      ...
# 223931                               21                        0
# 223932                               11                        0
# 223933                               11                        0
# 223934                               10                        0
# 223935                                7                        1
#
#         NumberRealEstateLoansOrLines  Late_60_89_Days  NumberOfDependents  \
# 0                                  0                0                   1
# 1                                  2                0                   0
# 2                                  2                2                   0
# 3                                  1                0                   0
# 4                                  2                0                   3
# ...                              ...              ...                 ...
# 223931                             2                0                   0
# 223932                             1                0                   2
# 223933                             2                2                   2
# 223934                             1                0                   3
# 223935                             1                0                   2
#
#         ...  Any90DayLate  IncomePerDependent  TotalCreditLines  \
# 0       ...             0          800.000000                 0
# 1       ...             0        13300.000000                19
# 2       ...             1         2877.000000                 7
# 3       ...             0         3800.000000                 7
# 4       ...             0         2300.000000                10
# ...     ...           ...                 ...               ...
# 223931  ...             0         1861.238444                23
# 223932  ...             0         2169.652673                12
# 223933  ...             0         2542.511178                13
# 223934  ...             0         1473.430523                12
# 223935  ...             1         3436.095045                 8
#
#         HighUtilizationFlag     DebtLoad  LatePerCreditLine  \
# 0                         1     0.000000           0.000000
# 1                         0  4980.735308           0.000000
# 2                         1  1680.267978           0.625000
# 3                         0  1821.092110           0.000000
# 4                         0  2413.520487           0.000000
# ...                     ...          ...                ...
# 223931                    0  2205.196870           0.024752
# 223932                    0  3900.415603           0.205863
# 223933                    0  4161.770810           0.344169
# 223934                    0  2051.557481           0.195724
# 223935                    0  1175.279101           0.268893
#
#         UtilizationPerLine  HasDependents  SeniorFlag  ZeroIncomeFlag
# 0                 1.000000              1           0               0
# 1                 0.004613              0           0               0
# 2                 0.136623              0           0               0
# 3                 0.039912              0           0               0
# 4                 0.002874              1           0               0
# ...                    ...            ...         ...             ...
# 223931            0.026282              0           0               0
# 223932            0.058398              1           0               0
# 223933            0.055497              1           0               0
# 223934            0.049119              1           0               0
# 223935            0.087904              1           0               0
#
# [223936 rows x 21 columns]

# %%
y_train_res
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 223931    1
# 223932    1
# 223933    1
# 223934    1
# 223935    1
# Name: Default_Status, Length: 223936, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(class_weight='balanced', min_samples_leaf=2,
#                        min_samples_split=5, n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
y_pred = rf.predict(X_test)
y_prob = rf.predict_proba(X_test)[:,1]

# %%
y_pred
y_prob
# Out:
# array([0.01709391, 0.34627052, 0.04998413, ..., 0.00944444, 0.1155874 ,
#        0.03379087])

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

print(classification_report(y_test, y_pred))
print("ROC-AUC Score:", roc_auc_score(y_test, y_prob))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95     27993
#            1       0.37      0.39      0.38      2005
#
#     accuracy                           0.91     29998
#    macro avg       0.66      0.67      0.67     29998
# weighted avg       0.92      0.91      0.92     29998
#
# ROC-AUC Score: 0.8445206777291046
# [[26634  1359]
#  [ 1218   787]]

# %%
sample = pd.DataFrame([{
 'Credit_Utilization':0.95,
 'age':44,
 'Late_30_59_Days':2,
 'DebtRatio':0.67,
 'MonthlyIncome':2800,
 'NumberOfOpenCreditLinesAndLoans':10,
 'NumberOfTimes90DaysLate':0,
 'NumberRealEstateLoansOrLines':1,
 'Late_60_89_Days':0,
 'NumberOfDependents':0,

 'TotalLatePayments':2,
 'Any90DayLate':0,
 'IncomePerDependent':2800,
 'TotalCreditLines':11,
 'HighUtilizationFlag':1,
 'DebtLoad':1876,
 'LatePerCreditLine':0.18,
 'UtilizationPerLine':0.08,
 'HasDependents':0,
 'SeniorFlag':0,
 'ZeroIncomeFlag':0
}])

# %%
rf.predict(sample)
rf.predict_proba(sample)
rf.predict(sample)
# Out:
# array([1])

# %%
import pickle

# Save model
pickle.dump(rf, open("credit_risk_model.pkl", "wb"))

# Save columns
pickle.dump(X.columns.tolist(), open("model_columns.pkl", "wb"))

# Save processed data
df.to_csv("processed_credit_risk.csv", index=False)
